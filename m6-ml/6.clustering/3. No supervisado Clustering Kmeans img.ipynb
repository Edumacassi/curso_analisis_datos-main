# %% [markdown]
# # Image Quatization
#
# La Cuantificación, involucrada en el procesamiento de imagen, es una técnica de compresión con pérdida que consiste en comprimir un rango de valores a un único valor. Cuando el número de símbolos discretos en un flujo dado se reduce, el flujo se vuelve más comprensible. Por ejemplo, reducir el número de colores requeridos para representar una imagen digital, hace posible reducir el tamaño de su archivo.

# %%
import seaborn as sns
# %matplotlib inline
import numpy as np
from sklearn import datasets
import matplotlib.pyplot as plt
sns.set()

# %%
# cargar una imagen con matplotlib
# from matplotlib import image as mpimg
#
# mpimg.imread("image.jpg")

# %%
# cargar una imagen con scikit
image = datasets.load_sample_image("flower.jpg")
image
# 2/255 color rojo debil(mas fuerte cuanto mas cerca a 255)
#19/255 color verde (mas fuuerte cuanto mas cerca de 255)
#13/255 color azul(mas fuerte cuanto mas cerca a 255)
# Out:
# array([[[ 2, 19, 13],
#         [ 3, 18, 13],
#         [ 7, 20, 13],
#         ...,
#         [ 1, 77, 64],
#         [ 0, 76, 64],
#         [ 0, 75, 63]],
#
#        [[ 1, 18, 12],
#         [ 3, 18, 13],
#         [ 7, 20, 13],
#         ...,
#         [ 0, 76, 64],
#         [ 1, 74, 65],
#         [ 1, 74, 65]],
#
#        [[ 2, 17, 12],
#         [ 6, 19, 12],
#         [ 7, 20, 13],
#         ...,
#         [ 1, 74, 65],
#         [ 1, 74, 67],
#         [ 1, 74, 67]],
#
#        ...,
#
#        [[ 0, 46, 40],
#         [ 1, 48, 40],
#         [ 1, 47, 37],
#         ...,
#         [ 5, 44, 26],
#         [ 6, 43, 26],
#         [ 7, 44, 27]],
#
#        [[ 0, 47, 41],
#         [ 1, 48, 40],
#         [ 1, 47, 37],
#         ...,
#         [ 6, 45, 27],
#         [ 7, 44, 27],
#         [ 7, 44, 27]],
#
#        [[ 0, 47, 41],
#         [ 1, 48, 40],
#         [ 0, 46, 36],
#         ...,
#         [ 7, 46, 28],
#         [ 8, 45, 28],
#         [ 9, 43, 27]]], dtype=uint8)

# %%
plt.figure(figsize=(6,6), dpi=100)
plt.imshow(image)
plt.grid(False)

# %%
type(image)
# Out:
# numpy.ndarray

# %%
image.nbytes
# Out:
# 819840

# %%
image.shape
#Primera dimension: 427, la altura de la imagen en pixeles
# Segunda dimension: 640, la anchura de la imagen en pixeles
# tercera dimencion: 3, los canales de color de la imagen ,Red(R), Green(G), Blue(B)
# Out:
# (427, 640, 3)

# %%
image.ndim
# Out:
# 3

# %%
print(image[0][0][0])
print(image[0][0][1])
print(image[0][0][2])
# Out:
# 2
# 19
# 13

# %%
print(image[150][300][0])
print(image[150][300][1])
print(image[150][300][2])
# Out:
# 237
# 122
# 41

# %% [markdown]
# # Imagen en 2d

# %%
image.shape
# Out:
# (427, 640, 3)

# %%
# obtener la imagen en 2d para usar en KMeans
height, width, channel = image.shape
image_2d = image.reshape(height * width, channel)
image_2d.shape
# Out:
# (273280, 3)

# %% [markdown]
# # KMeans

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=9)
labels = kmeans.fit_predict(image_2d)
labels
# Out:
# array([2, 2, 2, ..., 2, 2, 2])

# %%
kmeans.cluster_centers_
# Out:
# array([[  0.80874805,  78.64791513,  82.45486069],
#        [162.22058033, 115.42315959,  63.21507254],
#        [  6.09378713,  28.7233918 ,  20.36452477],
#        [211.10604632,  90.07618149,  26.41842188],
#        [226.65564455, 181.29819245, 127.29575712],
#        [  3.97825115,  53.96066623,  49.33196104],
#        [218.76624111, 147.32401422,  85.24802036],
#        [169.52461562,  23.61344929,   4.94113993],
#        [ 60.43875502,  64.78600115,  30.81267929]])

# %% [markdown]
# # Resultado a 3d

# %%
rgb_codes = kmeans.cluster_centers_.round(0).astype(int)
rgb_codes
# Out:
# array([[  1,  79,  82],
#        [162, 115,  63],
#        [  6,  29,  20],
#        [211,  90,  26],
#        [227, 181, 127],
#        [  4,  54,  49],
#        [219, 147,  85],
#        [170,  24,   5],
#        [ 60,  65,  31]])

# %%
image_3d = np.reshape(rgb_codes[labels], (height, width, channel))
image_3d
# Out:
# array([[[ 6, 29, 20],
#         [ 6, 29, 20],
#         [ 6, 29, 20],
#         ...,
#         [ 1, 79, 82],
#         [ 1, 79, 82],
#         [ 1, 79, 82]],
#
#        [[ 6, 29, 20],
#         [ 6, 29, 20],
#         [ 6, 29, 20],
#         ...,
#         [ 1, 79, 82],
#         [ 1, 79, 82],
#         [ 1, 79, 82]],
#
#        [[ 6, 29, 20],
#         [ 6, 29, 20],
#         [ 6, 29, 20],
#         ...,
#         [ 1, 79, 82],
#         [ 1, 79, 82],
#         [ 1, 79, 82]],
#
#        ...,
#
#        [[ 4, 54, 49],
#         [ 4, 54, 49],
#         [ 4, 54, 49],
#         ...,
#         [ 6, 29, 20],
#         [ 6, 29, 20],
#         [ 6, 29, 20]],
#
#        [[ 4, 54, 49],
#         [ 4, 54, 49],
#         [ 4, 54, 49],
#         ...,
#         [ 6, 29, 20],
#         [ 6, 29, 20],
#         [ 6, 29, 20]],
#
#        [[ 4, 54, 49],
#         [ 4, 54, 49],
#         [ 4, 54, 49],
#         ...,
#         [ 6, 29, 20],
#         [ 6, 29, 20],
#         [ 6, 29, 20]]])

# %%
plt.figure(figsize=(6,6), dpi=100)
plt.imshow(image_3d)

# %%
image.nbytes
# Out:
# 819840
